# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv', sep=';') 

df.head()
# Out:
#                                            Descrição Horário_de_publicação  \
# 0  De 0-10, quão exausta você ta? Pode desabafar ...      03/13/2023 16:03
# 1  E aí, sys?? \nO fogo no cool bate forte quando...      03/14/2023 08:03
# 2  Esse carrossel contém uma surpresa pra você! 🌸...      03/15/2023 13:03
# 3  Já salva pra treinar sempre e ir aprimorando a...      03/16/2023 14:03
# 4  E segue acontecendo todos os dias.\n\nNa madru...      03/17/2023 07:03
#
#                                Link_permanente      Tipo_de_publicação  \
# 0     https://www.instagram.com/p/Cpv08SeOKPa/  Carrossel do Instagram
# 1     https://www.instagram.com/p/CpxglUlPaWP/  Carrossel do Instagram
# 2     https://www.instagram.com/p/Cp0rJACIJID/  Carrossel do Instagram
# 3  https://www.instagram.com/reel/Cp3TZyRD6tM/       Reel do Instagram
# 4     https://www.instagram.com/p/Cp5K9k7uCEd/     Imagem do Instagram
#
#    Impressões  Alcance  Compartilhamentos  Seguimentos  Curtidas  Salvamentos  \
# ...

# %%
# Suponha que você tenha uma lista com os nomes das colunas a serem removidas
colunas_para_remover = ['Descrição', 'Task ID', 'Status', 'STATUS (drop down)','Link_permanente.1']

# Use o método drop para remover as colunas
df = df.drop(columns=colunas_para_remover)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 14 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Horário_de_publicação                          236 non-null    object
#  1   Link_permanente                                236 non-null    object
#  2   Tipo_de_publicação                             236 non-null    object
#  3   Impressões                                     236 non-null    int64
#  4   Alcance                                        236 non-null    int64
#  5   Compartilhamentos                              236 non-null    int64
#  6   Seguimentos                                    236 non-null    int64
#  7   Curtidas                                       236 non-null    int64
#  8   Salvamentos                                    236 non-null    int64
# ...

# %%
# Converter a coluna 'Horário_de_publicação' em um objeto datetime
df['Horário_de_publicação'] = pd.to_datetime(df['Horário_de_publicação'], format='%m/%d/%Y %H:%M')

# Extrair apenas a parte da data no formato brasileiro (DD/MM/YYYY)
df['Horário_de_publicação'] = df['Horário_de_publicação'].dt.strftime('%d/%m/%Y')

# %%
novo_nome_colunas = {
    'Categoria (drop down)': 'Categorias',
    'Expor produto (exclusivo p publi) (drop down)': 'Produto',
    'Etapa do funil (drop down)': 'Funil',
    'Horário_de_publicação' : 'Data_publicada'
}

# Use o método rename para renomear as colunas
df.rename(columns=novo_nome_colunas, inplace=True)

# %%
df.to_csv('Data_Set.csv', sep=';', index=False)
